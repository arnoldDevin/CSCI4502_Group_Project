# %%
# http://pbpython.com/market-basket-analysis.html
# https://rasbt.github.io/mlxtend/user_guide/frequent_patterns/association_rules/
#mlxtend is a python library with tools used to data science and machine learning
#If using jupyter through anaconda, download here: https://anaconda.org/conda-forge/mlxtend
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
#Use clean_test.csv file
df = pd.read_csv('yelp-dataset/clean_test.csv', low_memory = False, index_col=0)

# %%
#Replace values with more than 2 unique members with integers
df['Alcohol'].replace(to_replace = 'full_bar', value =2 , inplace = True )
df['Alcohol'].replace(to_replace = 'beer_and_wine', value =1 , inplace = True )

df['BYOB'].replace(to_replace = 'yes_free', value =1 , inplace = True )
df['BYOB'].replace(to_replace = 'no', value =0 , inplace = True )
df['BYOB'].replace(to_replace = 'yes_corkage', value =1 , inplace = True )

df['AgesAllowed'].replace(to_replace = 'allages', value =1 , inplace = True )
df['AgesAllowed'].replace(to_replace = '18', value =0 , inplace = True )
df['AgesAllowed'].replace(to_replace = '21', value =0 , inplace = True )

# %%
df = df.set_index('business_id')

# %%
df.drop('Alcohol', inplace=True, axis=1)
df.drop('BYOB', inplace=True, axis=1)
df.drop('AgesAllowed', inplace=True, axis=1)

# %%
#First 5 rows of dataframe
df.head()
#df['GoodForKids'].unique()
# Out:
#                         ByAppointmentOnly  BusinessAcceptsCreditCards  \
# business_id
# FYWN1wneV18bWNgQjJ2GNg  0                  0
# He-G7vWjzVUysIKrfNbPUQ  0                  0
# 8DShNS-LuFqpEWIp0HxijA  0                  0
# PfOCPjBrlQAnz__NXj9h_w  0                  0
# o9eMRCWt5PkpLDE0gOPtcQ  0                  0
#
#                         BusinessParking_garage  BusinessParking_street  \
# business_id
# FYWN1wneV18bWNgQjJ2GNg  1                       0
# He-G7vWjzVUysIKrfNbPUQ  0                       0
# 8DShNS-LuFqpEWIp0HxijA  0                       0
# PfOCPjBrlQAnz__NXj9h_w  0                       0
# o9eMRCWt5PkpLDE0gOPtcQ  0                       0
#
#                         BusinessParking_validated  BusinessParking_lot  \
# business_id
# FYWN1wneV18bWNgQjJ2GNg  0                          0
# He-G7vWjzVUysIKrfNbPUQ  0                          0
# 8DShNS-LuFqpEWIp0HxijA  0                          0
# PfOCPjBrlQAnz__NXj9h_w  0                          0
# o9eMRCWt5PkpLDE0gOPtcQ  0                          0
#
#                         BusinessParking_valet  HairSpecializesIn_coloring  \
# business_id
# FYWN1wneV18bWNgQjJ2GNg  0                      0
# He-G7vWjzVUysIKrfNbPUQ  0                      0
# 8DShNS-LuFqpEWIp0HxijA  0                      0
# PfOCPjBrlQAnz__NXj9h_w  0                      0
# o9eMRCWt5PkpLDE0gOPtcQ  0                      0
#
#                         HairSpecializesIn_africanamerican  \
# business_id
# FYWN1wneV18bWNgQjJ2GNg  0
# He-G7vWjzVUysIKrfNbPUQ  0
# 8DShNS-LuFqpEWIp0HxijA  0
# PfOCPjBrlQAnz__NXj9h_w  0
# o9eMRCWt5PkpLDE0gOPtcQ  0
#
#                         RestaurantsPriceRange2            ...              \
# business_id                                               ...
# FYWN1wneV18bWNgQjJ2GNg  0                                 ...
# He-G7vWjzVUysIKrfNbPUQ  0                                 ...
# 8DShNS-LuFqpEWIp0HxijA  0                                 ...
# PfOCPjBrlQAnz__NXj9h_w  0                                 ...
# o9eMRCWt5PkpLDE0gOPtcQ  0                                 ...
#
#                         DogsAllowed  BusinessAcceptsBitcoin  Open24Hours  \
# business_id
# FYWN1wneV18bWNgQjJ2GNg  0            0                       0
# He-G7vWjzVUysIKrfNbPUQ  0            0                       0
# 8DShNS-LuFqpEWIp0HxijA  0            0                       0
# PfOCPjBrlQAnz__NXj9h_w  0            0                       0
# o9eMRCWt5PkpLDE0gOPtcQ  0            0                       0
#
#                         DietaryRestrictions_gluten-free  \
# business_id
# FYWN1wneV18bWNgQjJ2GNg  0
# He-G7vWjzVUysIKrfNbPUQ  0
# 8DShNS-LuFqpEWIp0HxijA  0
# PfOCPjBrlQAnz__NXj9h_w  0
# o9eMRCWt5PkpLDE0gOPtcQ  0
#
#                         DietaryRestrictions_vegan  DietaryRestrictions_kosher  \
# business_id
# FYWN1wneV18bWNgQjJ2GNg  0                          0
# He-G7vWjzVUysIKrfNbPUQ  0                          0
# 8DShNS-LuFqpEWIp0HxijA  0                          0
# PfOCPjBrlQAnz__NXj9h_w  0                          0
# o9eMRCWt5PkpLDE0gOPtcQ  0                          0
#
#                         DietaryRestrictions_halal  \
# business_id
# FYWN1wneV18bWNgQjJ2GNg  0
# He-G7vWjzVUysIKrfNbPUQ  0
# 8DShNS-LuFqpEWIp0HxijA  0
# PfOCPjBrlQAnz__NXj9h_w  0
# o9eMRCWt5PkpLDE0gOPtcQ  0
#
#                         DietaryRestrictions_soy-free  \
# business_id
# FYWN1wneV18bWNgQjJ2GNg  0
# He-G7vWjzVUysIKrfNbPUQ  0
# 8DShNS-LuFqpEWIp0HxijA  0
# PfOCPjBrlQAnz__NXj9h_w  0
# o9eMRCWt5PkpLDE0gOPtcQ  0
#
#                         DietaryRestrictions_vegetarian  \
# business_id
# FYWN1wneV18bWNgQjJ2GNg  0
# He-G7vWjzVUysIKrfNbPUQ  0
# 8DShNS-LuFqpEWIp0HxijA  0
# PfOCPjBrlQAnz__NXj9h_w  0
# o9eMRCWt5PkpLDE0gOPtcQ  0
#
#                         RestaurantsCounterService
# business_id
# FYWN1wneV18bWNgQjJ2GNg  0
# He-G7vWjzVUysIKrfNbPUQ  0
# 8DShNS-LuFqpEWIp0HxijA  0
# PfOCPjBrlQAnz__NXj9h_w  0
# o9eMRCWt5PkpLDE0gOPtcQ  0
#
# [5 rows x 52 columns]

# %%
#Minimum support low simply to see the most amount of Lift correlations
frequent_itemsets = apriori(df, min_support=0.001, use_colnames=True)

# %%
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows', None)  
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=100)
rules.head(1000)

#115 Combinations with Lift >= 1
#35 Combinations with Lift >= 50
#17 Combinations with Lift >= 100
# Out:
#                                                           antecedants  \
# 0   (GoodForMeal_dinner)
# 1   (CoatCheck)
# 2   (GoodForMeal_brunch)
# 3   (CoatCheck)
# 4   (BestNights_monday, BusinessParking_valet)
# 5   (GoodForMeal_dinner)
# 6   (GoodForMeal_breakfast, BusinessParking_valet)
# 7   (GoodForMeal_dinner)
# 8   (BestNights_monday, GoodForMeal_breakfast)
# 9   (GoodForMeal_dinner)
# 10  (BestNights_monday, GoodForMeal_breakfast, BusinessParking_valet)
# 11  (GoodForMeal_dinner, BestNights_monday)
# 12  (GoodForMeal_dinner, GoodForMeal_breakfast)
# 13  (GoodForMeal_dinner, BusinessParking_valet)
# 14  (BestNights_monday, GoodForMeal_breakfast)
# 15  (BestNights_monday, BusinessParking_valet)
# 16  (GoodForMeal_breakfast, BusinessParking_valet)
# 17  (GoodForMeal_dinner)
#
#                                                           consequents  \
# 0   (CoatCheck)
# 1   (GoodForMeal_dinner)
# 2   (CoatCheck)
# 3   (GoodForMeal_brunch)
# 4   (GoodForMeal_dinner)
# 5   (BestNights_monday, BusinessParking_valet)
# 6   (GoodForMeal_dinner)
# 7   (GoodForMeal_breakfast, BusinessParking_valet)
# 8   (GoodForMeal_dinner)
# 9   (BestNights_monday, GoodForMeal_breakfast)
# 10  (GoodForMeal_dinner)
# 11  (GoodForMeal_breakfast, BusinessParking_valet)
# 12  (BestNights_monday, BusinessParking_valet)
# 13  (BestNights_monday, GoodForMeal_breakfast)
# 14  (GoodForMeal_dinner, BusinessParking_valet)
# 15  (GoodForMeal_dinner, GoodForMeal_breakfast)
# 16  (GoodForMeal_dinner, BestNights_monday)
# 17  (BestNights_monday, GoodForMeal_breakfast, BusinessParking_valet)
#
#     antecedent support  consequent support   support  confidence        lift  \
# 0   0.007426            0.001638            0.001217  0.163862    100.055083
# 1   0.001638            0.007426            0.001217  0.742972    100.055083
# 2   0.001631            0.001638            0.001059  0.649194    396.401752
# 3   0.001638            0.001631            0.001059  0.646586    396.401752
# 4   0.002092            0.007426            0.001605  0.767296    103.330726
# 5   0.007426            0.002092            0.001605  0.216120    103.330726
# 6   0.004953            0.007426            0.003762  0.759628    102.298161
# 7   0.007426            0.004953            0.003762  0.506643    102.298161
# 8   0.001664            0.007426            0.001408  0.845850    113.909522
# 9   0.007426            0.001664            0.001408  0.189548    113.909522
# 10  0.001256            0.007426            0.001105  0.879581    118.452080
# 11  0.002111            0.004953            0.001105  0.523364    105.674449
# 12  0.004821            0.002092            0.001105  0.229195    109.581920
# 13  0.005452            0.001664            0.001105  0.202654    121.785322
# 14  0.001664            0.005452            0.001105  0.664032    121.785322
# 15  0.002092            0.004821            0.001105  0.528302    109.581920
# 16  0.004953            0.002111            0.001105  0.223108    105.674449
# 17  0.007426            0.001256            0.001105  0.148804    118.452080
#
#     leverage  conviction
# 0   0.001205  1.194016
# 1   0.001205  3.861735
# 2   0.001056  2.845906
# 3   0.001056  2.824930
# 4   0.001589  4.265387
# 5   0.001589  1.273038
# 6   0.003725  4.129329
# 7   0.003725  2.016891
# 8   0.001395  6.439008
# 9   0.001395  1.231827
# 10  0.001096  8.242683
# 11  0.001095  2.087648
# 12  0.001095  1.294632
# 13  0.001096  1.252073
# 14  0.001096  2.960241
# 15  0.001095  2.109779
# 16  0.001095  1.284462
# 17  0.001096  1.173342
